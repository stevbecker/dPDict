# %% [markdown]
# Learn Markdown by Doing
# =======================
#
# ####Table of Contents
# [Headers](#headers)
# [Paragraphs](#paragraphs)
# [Lists](#lists)
# [Horizontal Rules](#rules)
# [Blockquotes](#blockquotes)
# [Codes](#codes)
# [Links](#links)
#
# * [Images](#images)
#
# [Raw texts](#rawtexts)
#
#
# <a name="headers"/>
# # H1
# H1 another way
# ==============
# ## H2
# H2 another way
# --------------
# ### H3
# #### H4
#
#
# <a name="paragraphs"/>
# This is a paragraph (there are ***two spaces*** after the period for a line break).
# This is another paragraph.
#
# This is the third paragraph.
#
# <a name="lists"/>
# **Unordered Lists**
#
# * use asterisk \*
#   * unorderded sub-list itme
# + use plus sign \+
#   + sub-list item
# - use dash \-
#
# *Ordered Lists*
#
# 1. first ordered list item
# 1. second ordered list item (number doesn't matter, it's just a number)
#   1. sub-list item
#   1. sub-list item
#
#
#
# <a name="rules"/>
# **Horizontal Rule**
#
# ---
# by Hyphens
# ***
# by Asterisks
#
# <a name="blockquotes"/>
# **Blockquotes**
#
# > This is a quote.
# > More quotes.
#
#
# <a name="codes"/>
# **Inline Code**
#
# Inline `code` has `back-tick around` it.
#
# ```
# #Use triple back-ticks for code
# def func():
#   print 'hello'
# ```
#     #Use indent for code
#     def fun():
#         print 'hey'
#
#
# <a name="links"/>
# this is a link to [my website](http://tada-alchemy.com "tada Alchemy") which focuses on web analytics for marketing.
#
#
# <a name="images"/>
# this is the twitter logo ![alt text](https://g.twimg.com/About_logoUsage.png "Twitter bird")
#
# this is Twitter logo
# ![alt text][twitter logo]
# [twitter logo]: https://g.twimg.com/About_logoUsage.png "bird"
#
#
# <a name="rawtexts"/>
# ```
# raw text
# no-highlight
# here is raw text
# ---here is raw text
# ***raw
# ```

# %% [markdown]
# ### Source
# ```$$
# \left( \sum_{k=1}^n a_k b_k \right)^2 \leq \left( \sum_{k=1}^n a_k^2 \right) \left( \sum_{k=1}^n b_k^2 \right)
# $$
# ```
# ### Display
# $$
# \left( \sum_{k=1}^n a_k b_k \right)^2 \leq \left( \sum_{k=1}^n a_k^2 \right) \left( \sum_{k=1}^n b_k^2 \right)
# $$
